# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
print(f"Backend: {plt.get_backend()}")

import numpy as np
x=np.linspace(0,5,11)
y=x**2
# Out:
# Backend: notebook

# %%
fig=plt.figure()

axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.4,0.2])

axes1.plot(x,y)
axes1.set_title('Larger Plot')

axes2.plot(y,x)
axes2.set_title('Smaller Plot')
# Out:
# <img src="data:image/png;base64,..." width="640.4999809116131">
# Text(0.5, 1.0, 'Smaller Plot')

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
for current_ax in axes:
    current_ax.plot(x,y)
# Out:
# <img src="data:image/png;base64,..." width="640.4999809116131">

# %%
axes
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y)
axes[0].set_title('First plot')

axes[1].plot(y,x)
axes[1].set_title('Second plot')

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640.4999809116131">

# %%
fig=plt.subplots(nrows=2,ncols=1,figsize=(8,2))
axes[0].plot(x,y)
axes[1].plot(y,x)
# Out:
# <img src="data:image/png;base64,..." width="800.9999761283404">

# %%
# Out:
# (<Figure size 532.667x132.667 with 2 Axes>,
#  array([<Axes: >, <Axes: >], dtype=object))
